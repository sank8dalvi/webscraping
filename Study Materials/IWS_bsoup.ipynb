# %% [markdown]
# # <u>BeautifulSoup</u>
# ***

# %% [markdown]
# ## INTRODUCTION TO HTML
# ***
# Basic HTML Document Layout :
# <img src="https://ischool.syr.edu/infospace/wp-content/files/2012/03/htmlintro.png" />

# %%
#Open Html Layout Demo
import webbrowser
webbrowser.open_new_tab('htmllayout.html')
# Out:
# True

# %% [markdown]
# # Class and Id's with HTML
# ***
# The HTML class attribute is used to define equal styles for elements with the same class name.
# So, all HTML elements with the same class attribute will have the same format and style.
#
#
# Blog Post:  <a href="https://css-tricks.com/the-difference-between-id-and-class/">Difference between Class and Id's</a>

# %%
#Opens cl.html
webbrowser.open_new_tab('cl.html')
# Out:
# True

# %%
#Opens Numbers website
webbrowser.open_new_tab("https://www.the-numbers.com/daily-box-office-chart")

# %%
from bs4 import BeautifulSoup
import requests

url = "https://www.the-numbers.com/daily-box-office-chart"
req = requests.get(url)
print(BeautifulSoup(req.content,'html.parser').prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <!-- Global site tag (gtag.js) - Google Analytics -->
#   <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-1343128-1">
#   </script>
#   <script>
#    window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'UA-1343128-1');
#   </script>
#   <meta content='(PICS-1.1 "https://www.icra.org/ratingsv02.html" l gen true for "https://www.the-numbers.com/" r (cb 1 lz 1 nz 1 oz 1 vz 1) "https://www.rsac.org/ratingsv01.html" l gen true for "https://www.the-numbers.com/" r (n 0 s 0 v 0 l 0))' http-equiv="PICS-Label"/>
#   <!--<meta http-equiv="Content-Type" content="text/html; charset=ISO-8859-1" >-->
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="telephone=no" name="format-detection"/>
#   <!-- for apple mobile -->
#   <meta content="521546213" property="fb:admins">
#    <meta content="initial-scale=1" name="viewport"/>
#    <meta content="Daily Domestic Box Office Chart for Thursday March 21, 2019" name="description"/>
#    <meta content="NOODP" name="robots"/>
#    <meta content="Box Office, Chart, Domestic, Daily, Thursday March 21, 2019" name="keywords"/>
#    <title>
#     The Numbers - Daily Box Office Chart for Thursday March 21, 2019
#    </title>
#    <link href="/resources/the-numbers-desktop-combined.css" rel="stylesheet" type="text/css"/>
#    <link href="https://m.the-numbers.com/daily-box-office-chart" media="only screen and (max-width: 640px)" rel="alternate"/>
#    <script type="text/javascript">
#     if (screen.width <= 640)
# 	{
#         window.location = "https://m.the-numbers.com/daily-box-office-chart";
#     }
#    </script>
#    <!-- Begin comScore Tag -->
#    <script async="">
#     var _comscore = _comscore || [];
# _comscore.push({ c1: "2", c2: "9873768" });
# (function() {
#  var s = document.createElement("script"), el = document.getElementsByTagName("script")[0]; s.async = true;
#  s.src = (document.location.protocol == "https:" ? "https://sb" : "http://b") + ".scorecardresearch.com/beacon.js";
#  el.parentNode.insertBefore(s, el);
#  })();
#    </script>
#    <noscript>
#     <img src="https://b.scorecardresearch.com/p?c1=2&amp;c2=9873768&amp;cv=2.0&amp;cj=1"/>
#    </noscript>
#    <!-- End comScore Tag -->
#    <!-- Header Tag Code -->
#    <script data-cfasync="false" type="text/javascript">
#     /*<![CDATA[*/(function (a, c, s, u){'Insticator'in a || (a.Insticator={ad:{loadAd: function (b){Insticator.ad.q.push(b)}, q: []}, helper:{}, embed:{}, version: "3.0", q: [], load: function (t, o){Insticator.q.push({t: t, o: o})}}); var b=c.createElement(s); b.src=u; b.async=!0; var d=c.getElementsByTagName(s)[0]; d.parentNode.insertBefore(b, d)})(window, document, 'script', '//d2na2p72vtqyok.cloudfront.net/client-embed/65b21a35-f662-4947-80ea-07d6b99277bf.js');/*
# ]]>*/
#    </script>
#    <!-- End Header Tag Code -->
#   </meta>
#  </head>
#  <body>
#   <script>
#    window.fbAsyncInit = function() {
#     FB.init({
#       appId            : '1585976611658631',
#       autoLogAppEvents : true,
#       xfbml            : true,
#       version          : 'v2.9'
#     });
#     FB.AppEvents.logPageView();
#   };
#
#   (function(d, s, id){
#      var js, fjs = d.getElementsByTagName(s)[0];
#      if (d.getElementById(id)) {return;}
#      js = d.createElement(s); js.id = id;
#      js.src = "//connect.facebook.net/en_US/sdk.js";
#      fjs.parentNode.insertBefore(js, fjs);
#    }(document, 'script', 'facebook-jssdk'));
#   </script>
#   <div id="wrap">
#    <div id="header">
#     <a href="/">
#      <img alt="The Numbers - Where Data and Movies Meet" border="0" height="67" src="/images/the-numbers-banner.png" width="524"/>
#      ®
#      <br/>
#      Where Data and the Movie Business Meet
#     </a>
#    </div>
#    <div id="header_right" style="background: #663366; width:200px; height: 96px;">
#     <div style="float:right;">
#      Follow us on
#      <a href="https://www.facebook.com/TheNumbers" target="_blank">
#       <img height="32" src="https://www.the-numbers.com/images/icons/facebook.png" style="border:none;" title="Follow The Numbers on Facebook" width="32"/>
#      </a>
#      <a href="https://www.twitter.com/MovieNumbers" target="_blank" title="Follow The Numbers on Twitter">
#       <img height="32" src="https://www.the-numbers.com/images/icons/twitter.png" style="border:none;" width="32"/>
#      </a>
#     </div>
#    </div>
#    <div id="nav">
#     <ul>
#      <li>
#       <a href="/news">
#        News
#       </a>
#       <ul>
#        <li>
#         <a href="/news">
#          Latest News
#         </a>
#        </li>
#        <li>
#         <a href="/movies/release-schedule">
#          Release Schedule
#         </a>
#        </li>
#        <li>
#         <a href="/on-this-day">
#          On This Day
#         </a>
#        </li>
#       </ul>
#      </li>
#      <li>
#       <a href="/box-office">
#        Box Office
#       </a>
#       <ul>
#        <li>
#         <a href="/daily-box-office-chart">
#          Daily Chart
#         </a>
#        </li>
#        <li>
#         <a href="/weekend-box-office-chart">
#          Weekend Chart
#         </a>
#        </li>
#        <li>
#         <a href="/weekly-box-office-chart">
#          Weekly Chart
#         </a>
#        </li>
#        <li>
#         <a href="/market/">
#          Theatrical Market
#         </a>
#        </li>
#        <li>
#         <a href="/international-charts-overview">
#          International Charts
#         </a>
#        </li>
#        <li>
#         <a href="/box-office-records/">
#          Records
#         </a>
#        </li>
#        <li>
#         <a href="/box-office">
#          Chart Index
#         </a>
#        </li>
#        <li>
#         <a href="/movies/release-schedule">
#          Release Schedule
#         </a>
#        </li>
#        <li>
#         <a href="/box-office-records/worldwide/all-movies/cumulative/released-in-2019">
#          2019 Worldwide
#         </a>
#        </li>
#       </ul>
#      </li>
#      <li>
#       <a href="/weekly-dvd-sales-chart">
#        Home Video
#       </a>
#       <ul>
#        <li>
#         <a href="/weekly-dvd-sales-chart">
#          Weekly DVD Chart
#         </a>
#        </li>
#        <li>
#         <a href="/weekly-bluray-sales-chart">
#          Weekly Blu-ray Chart
#         </a>
#        </li>
#        <li>
#         <a href="/weekly-video-sales-chart">
#          Weekly Combined DVD+Blu-ray Chart
#         </a>
#        </li>
#        <li>
#         <a href="/home-market/dvd-sales/2019">
#          2019 DVD Chart
#         </a>
#        </li>
#        <li>
#         <a href="/home-market/bluray-sales/2019">
#          2019 Blu-ray Chart
#         </a>
#        </li>
#        <li>
#         <a href="/home-market/packaged-media-sales/2019">
#          2019 Combined Chart
#         </a>
#        </li>
#        <li>
#         <a href="/alltime-bluray-sales-chart">
#          All-Time Blu-ray
#         </a>
#        </li>
#        <li>
#         <a href="/home-market/release-schedule">
#          Release Schedule
#         </a>
#        </li>
#        <li>
#         <a href="/home-market/distributors">
#          Distributors
#         </a>
#        </li>
#       </ul>
#      </li>
#      <li>
#       <a href="/movies">
#        Movies
#       </a>
#       <ul>
#        <li>
#         <a href="/movie/budgets">
#          Budgets and Finances
#         </a>
#        </li>
#        <li>
#         <a href="/movies/franchises">
#          Franchises
#         </a>
#        </li>
#        <li>
#         <a href="/movies/keywords">
#          Keywords
#         </a>
#        </li>
#        <li>
#         <a href="/movies">
#          Movie Index
#         </a>
#        </li>
#        <li>
#         <a href="/movies/release-schedule">
#          Release Schedule
#         </a>
#        </li>
#        <li>
#         <a href="/movies/most-anticipated">
#          Most Anticipated
#         </a>
#        </li>
#        <li>
#         <a href="/movies/trending">
#          Trending Movies
#         </a>
#        </li>
#        <li>
#         <a href="/movies/production-companies/">
#          Production Companies
#         </a>
#        </li>
#        <li>
#         <a href="/movies/production-countries/">
#          Production Countries
#         </a>
#        </li>
#        <li>
#         <a href="/movies/comparisons">
#          Comparisons
#         </a>
#        </li>
#        <li>
#         <a href="/movies/report-builder">
#          Report Builder
#         </a>
#        </li>
#       </ul>
#      </li>
#      <li>
#       <a href="/people">
#        People
#       </a>
#       <ul>
#        <li>
#         <a href="/bankability">
#          Bankability
#         </a>
#        </li>
#        <li>
#         <a href="/box-office-star-records/">
#          Records
#         </a>
#        </li>
#        <li>
#         <a href="/people">
#          People Index
#         </a>
#        </li>
#        <li>
#         <a href="/people/trending">
#          Trending People
#         </a>
#        </li>
#        <li>
#         <a href="/box-office-star-records/domestic/yearly-acting/highest-grossing-2019-stars">
#          Highest Grossing Stars of 2019
#         </a>
#        </li>
#       </ul>
#      </li>
#      <li>
#       <a href="/oscars">
#        Oscars
#       </a>
#      </li>
#      <li>
#       <a href="/research-analysis">
#        Research &amp; Data
#       </a>
#      </li>
#      <li style="background: #ffcc00;">
#       <a href="https://m.the-numbers.com/daily-box-office-chart?from_desktop=Yes" style="background: #ffcc00;">
#        Mobile Website
#       </a>
#      </li>
#     </ul>
#    </div>
#    <div id="banneradnew">
#     <center>
#      <script type="text/javascript">
#       <!--
# e9 = new Object();
# e9.size = "728x90,970x250";
# //-->
#      </script>
#      <script src="//tags.expo9.exponential.com/tags/TheNumbers/ROS/tags.js" type="text/javascript">
#      </script>
#     </center>
#    </div>
#    <div id="main">
#     <div id="page_filling_chart">
#      <div class="alignright" style="margin: 16px 0px -16px 0px;">
#       <ul id="social_horizontal">
#        <li>
#         <a class="twitter-share-button" data-text="The Numbers - Daily Box Office Chart for Thursday March 21, 2019" data-via="MovieNumbers" href="https://twitter.com/share" rel="nofollow">
#         </a>
#         <script>
#          !function(d,s,id){var js,fjs=d.getElementsByTagName(s)[0];if(!d.getElementById(id)){js=d.createElement(s);js.id=id;js.src="//platform.twitter.com/widgets.js";fjs.parentNode.insertBefore(js,fjs);}}(document,"script","twitter-wjs");
#         </script>
#        </li>
#        <li>
#         <div class="fb-like" data-action="like" data-colorscheme="light" data-href="https://www.the-numbers.com/daily-box-office-chart" data-layout="button_count" data-send="false" data-show-faces="false">
#         </div>
#        </li>
#        <li>
#         <script src="//platform.linkedin.com/in.js" type="text/javascript">
#         </script>
#         <script data-counter="right" type="IN/Share">
#         </script>
#        </li>
#       </ul>
#      </div>
#      <div class="clearfloats">
#      </div>
#      <h1>
#       Daily Domestic Chart for Thursday March 21, 2019
#      </h1>
#     </div>
#     <table class="pintable">
#      <tr>
#       <td class="previous">
#        <a href="/box-office-chart/daily/2019/03/20">
#         ← Previous Chart
#        </a>
#       </td>
#       <td class="index">
#        <a href="/box-office">
#         Chart Index
#        </a>
#       </td>
#       <td class="next">
#       </td>
#      </tr>
#     </table>
#     <div id="page_filling_chart">
#      <div class="clearfloats">
#      </div>
#      <center>
#       <table align="CENTER" border="0" cellpadding="1" cellspacing="0">
#        <tr>
#         <th>
#         </th>
#         <th>
#         </th>
#         <th>
#          Movie
#         </th>
#         <th>
#          Distributor
#         </th>
#         <th>
#          Gross
#         </th>
#         <th>
#          Change
#         </th>
#         <th>
#          Thtrs.
#         </th>
#         <th>
#          Per Thtr.
#         </th>
#         <th>
#          Total Gross
#         </th>
#         <th>
#          Days
#         </th>
#        </tr>
#        <tr>
#         <td class="data">
#          1
#         </td>
#         <td class="data">
#          (1)
#         </td>
#         <td>
#          <b>
#           <a href="/movie/Captain-Marvel-(2019)#tab=box-office">
#            Captain Marvel
#           </a>
#          </b>
#         </td>
#         <td>
#          <a href="/market/distributor/Walt-Disney">
#           Walt Disney
#          </a>
#         </td>
#         <td class="data">
#          $4,226,298
#         </td>
#         <td class="data chart_down">
#          -7%
#         </td>
#         <td class="data">
#          4,310
#         </td>
#         <td class="data chart_grey">
#          $981
#         </td>
#         <td class="data">
#          $286,477,835
#         </td>
#         <td class="data">
#          14
#         </td>
#        </tr>
#        <tr bgcolor="#ffeeff">
#         <td class="data">
#          2
#         </td>
#         <td class="data">
#          (2)
#         </td>
#         <td>
#          <b>
#           <a href="/movie/Five-Feet-Apart-(2019)#tab=box-office">
#            Five Feet Apart
#           </a>
#          </b>
#         </td>
#         <td>
#          <a href="/market/distributor/Lionsgate">
#           Lionsgate
#          </a>
#         </td>
#         <td class="data">
#          $991,549
#         </td>
#         <td class="data">
#          n/c
#         </td>
#         <td class="data">
#          2,803
#         </td>
#         <td class="data chart_grey">
#          $354
#         </td>
#         <td class="data">
#          $17,711,064
#         </td>
#         <td class="data">
#          7
#         </td>
#        </tr>
#        <tr>
#         <td class="data">
#          3
#         </td>
#         <td class="data">
#          (3)
#         </td>
#         <td>
#          <b>
#           <a href="/movie/Wonder-Park-(2019)#tab=box-office">
#            Wonder Park
#           </a>
#          </b>
#         </td>
#         <td>
#          <a href="/market/distributor/Paramount-Pictures">
#           Paramount Pictures
#          </a>
#         </td>
#         <td class="data">
#          $965,230
#         </td>
#         <td class="data chart_down">
#          -2%
#         </td>
#         <td class="data">
#          3,838
#         </td>
#         <td class="data chart_grey">
#          $251
#         </td>
#         <td class="data">
#          $20,477,304
#         </td>
#         <td class="data">
#          7
#         </td>
#        </tr>
#        <tr bgcolor="#ffeeff">
#         <td class="data">
#          4
#         </td>
#         <td class="data">
#          (4)
#         </td>
#         <td>
#          <b>
#           <a href="/movie/How-to-Train-Your-Dragon-The-Hidden-World-(2019)#tab=box-office">
#            How to Train Your Dragon: T…
#           </a>
#          </b>
#         </td>
#         <td>
#          <a href="/market/distributor/Universal">
#           Universal
#          </a>
#         </td>
#         <td class="data">
#          $804,620
#         </td>
#         <td class="data chart_down">
#          -4%
#         </td>
#         <td class="data">
#          3,727
#         </td>
#         <td class="data chart_grey">
#          $216
#         </td>
#         <td class="data">
#          $139,219,630
#         </td>
#         <td class="data">
#          28
#         </td>
#        </tr>
#        <tr>
#         <td class="data">
#          5
#         </td>
#         <td class="data">
#          (5)
#         </td>
#         <td>
#          <b>
#           <a href="/movie/Tyler-Perrys-A-Madea-Family-Funeral-(2019)#tab=box-office">
#            Tyler Perryâs A Madea Fam…
#           </a>
#          </b>
#         </td>
#         <td>
#          <a href="/market/distributor/Lionsgate">
#           Lionsgate
#          </a>
#         </td>
#         <td class="data">
#          $491,555
#         </td>
#         <td class="data chart_down">
#          -12%
#         </td>
#         <td class="data">
#          2,350
#         </td>
#         <td class="data chart_grey">
#          $209
#         </td>
#         <td class="data">
#          $61,381,232
#         </td>
#         <td class="data">
#          21
#         </td>
#        </tr>
#        <tr bgcolor="#ffeeff">
#         <td class="data chart_up">
#          <b>
#           6
#          </b>
#         </td>
#         <td class="data">
#          (9)
#         </td>
#         <td>
#          <b>
#           <a href="/movie/Lego-Movie-2-The-Second-Part-The-(2019)#tab=box-office">
#            The LEGO Movie 2: The Secon…
#           </a>
#          </b>
#         </td>
#         <td>
#          <a href="/market/distributor/Warner-Bros">
#           Warner Bros.
#          </a>
#         </td>
#         <td class="data">
#          $191,880
#         </td>
#         <td class="data chart_down">
#          -6%
#         </td>
#         <td class="data">
#          2,046
#         </td>
#         <td class="data chart_grey">
#          $94
#         </td>
#         <td class="data">
#          $102,203,550
#         </td>
#         <td class="data">
#          42
#         </td>
#        </tr>
#        <tr>
#         <td class="data chart_up">
#          <b>
#           7
#          </b>
#         </td>
#         <td class="data">
#          (8)
#         </td>
#         <td>
#          <b>
#           <a href="/movie/No-Manches-Frida-2-(2019)#tab=box-office">
#            No Manches Frida 2
#           </a>
#          </b>
#         </td>
#         <td>
#          <a href="/market/distributor/Lionsgate">
#           Lionsgate
#          </a>
#         </td>
#         <td class="data">
#          $184,371
#         </td>
#         <td class="data chart_down">
#          -16%
#         </td>
#         <td class="data">
#          472
#         </td>
#         <td class="data chart_grey">
#          $391
#         </td>
#         <td class="data">
#          $4,846,279
#         </td>
#         <td class="data">
#          7
#         </td>
#        </tr>
#        <tr bgcolor="#ffeeff">
#         <td class="data chart_down">
#          8
#         </td>
#         <td class="data">
#          (6)
#         </td>
#         <td>
#          <b>
#           <a href="/movie/Captive-State-(2019)#tab=box-office">
#            Captive State
#           </a>
#          </b>
#         </td>
#         <td>
#          <a href="/market/distributor/Focus-Features">
#           Focus Features
#          </a>
#         </td>
#         <td class="data">
#          $184,315
#         </td>
#         <td class="data chart_down">
#          -29%
#         </td>
#         <td class="data">
#          2,548
#         </td>
#         <td class="data chart_grey">
#          $72
#         </td>
#         <td class="data">
#          $4,310,660
#         </td>
#         <td class="data">
#          7
#         </td>
#        </tr>
#        <tr>
#         <td class="data chart_down">
#          9
#         </td>
#         <td class="data">
#          (7)
#         </td>
#         <td>
#          <b>
#           <a href="/movie/Alita-Battle-Angel-(2019)#tab=box-office">
#            Alita: Battle Angel
#           </a>
#          </b>
#         </td>
#         <td>
#          <a href="/market/distributor/20th-Century-Fox">
#           20th Century Fox
#          </a>
#         </td>
#         <td class="data">
#          $166,276
#         </td>
#         <td class="data chart_down">
#          -25%
#         </td>
#         <td class="data">
#          1,696
#         </td>
#         <td class="data chart_grey">
#          $98
#         </td>
#         <td class="data">
#          $82,733,050
#         </td>
#         <td class="data">
#          36
#         </td>
#        </tr>
#        <tr bgcolor="#ffeeff">
#         <td class="data">
#          10
#         </td>
#         <td class="data">
#          (10)
#         </td>
#         <td>
#          <b>
#           <a href="/movie/Green-Book-(2018)#tab=box-office">
#            Green Book
#           </a>
#          </b>
#         </td>
#         <td>
#          <a href="/market/distributor/Universal">
#           Universal
#          </a>
#         </td>
#         <td class="data">
#          $126,355
#         </td>
#         <td class="data chart_down">
#          -21%
#         </td>
#         <td class="data">
#          1,320
#         </td>
#         <td class="data chart_grey">
#          $96
#         </td>
#         <td class="data">
#          $83,279,956
#         </td>
#         <td class="data">
#          126
#         </td>
#        </tr>
#        <tr>
#         <td class="data">
#          11
#         </td>
#         <td class="data">
#          (11)
#         </td>
#         <td>
#          <b>
#           <a href="/movie/Apollo-11-(Documentary)-(2019)#tab=box-office">
#            Apollo 11
#           </a>
#          </b>
#         </td>
#         <td>
#          <a href="/market/distributor/Neon">
#           Neon
#          </a>
#         </td>
#         <td class="data">
#          $123,044
#         </td>
#         <td class="data chart_down">
#          -21%
#         </td>
#         <td class="data">
#          588
#         </td>
#         <td class="data chart_grey">
#          $209
#         </td>
#         <td class="data">
#          $6,065,437
#         </td>
#         <td class="data">
#          21
#         </td>
#        </tr>
#        <tr bgcolor="#ffeeff">
#         <td class="data">
#          12
#         </td>
#         <td class="data">
#          (12)
#         </td>
#         <td>
#          <b>
#           <a href="/movie/Isnt-it-Romantic-(2019)#tab=box-office">
#            Isnât it Romantic
#           </a>
#          </b>
#         </td>
#         <td>
#          <a href="/market/distributor/Warner-Bros">
#           Warner Bros.
#          </a>
#         </td>
#         <td class="data">
#          $106,215
#         </td>
#         <td class="data chart_down">
#          -19%
#         </td>
#         <td class="data">
#          1,366
#         </td>
#         <td class="data chart_grey">
#          $78
#         </td>
#         <td class="data">
#          $46,877,090
#         </td>
#         <td class="data">
#          37
#         </td>
#        </tr>
#        <tr>
#         <td class="data">
#          13
#         </td>
#         <td class="data">
#          (13)
#         </td>
#         <td>
#          <b>
#           <a href="/movie/Fighting-With-My-Family-(2019)#tab=box-office">
#            Fighting With My Family
#           </a>
#          </b>
#         </td>
#         <td>
#          <a href="/market/distributor/United-Artists">
#           United Artists
#          </a>
#         </td>
#         <td class="data">
#          $102,653
#         </td>
#         <td class="data chart_down">
#          -21%
#         </td>
#         <td class="data">
#          1,580
#         </td>
#         <td class="data chart_grey">
#          $65
#         </td>
#         <td class="data">
#          $21,419,677
#         </td>
#         <td class="data">
#          36
#         </td>
#        </tr>
#        <tr bgcolor="#ffeeff">
#         <td class="data">
#          14
#         </td>
#         <td class="data">
#          (14)
#         </td>
#         <td>
#          <b>
#           <a href="/movie/Upside-The-(2019)#tab=box-office">
#            The Upside
#           </a>
#          </b>
#         </td>
#         <td>
#          <a href="/market/distributor/STX-Entertainment">
#           STX Entertainment
#          </a>
#         </td>
#         <td class="data">
#          $78,963
#         </td>
#         <td class="data chart_down">
#          -18%
#         </td>
#         <td class="data">
#          880
#         </td>
#         <td class="data chart_grey">
#          $90
#         </td>
#         <td class="data">
#          $106,282,456
#         </td>
#         <td class="data">
#          70
#         </td>
#        </tr>
#        <tr>
#         <td class="data">
#          15
#         </td>
#         <td class="data">
#          (-)
#         </td>
#         <td>
#          <b>
#           <a href="/movie/What-Men-Want-(2019)#tab=box-office">
#            What Men Want
#           </a>
#          </b>
#         </td>
#         <td>
#          <a href="/market/distributor/Paramount-Pictures">
#           Paramount Pictures
#          </a>
#         </td>
#         <td class="data">
#          $52,783
#         </td>
#         <td class="data chart_down">
#          -27%
#         </td>
#         <td class="data">
#          587
#         </td>
#         <td class="data chart_grey">
#          $90
#         </td>
#         <td class="data">
#          $53,741,163
#         </td>
#         <td class="data">
#          42
#         </td>
#        </tr>
#        <tr bgcolor="#ffeeff">
#         <td class="data">
#          -
#         </td>
#         <td class="data">
#          (15)
#         </td>
#         <td>
#          <b>
#           <a href="/movie/Greta-(2019)#tab=box-office">
#            Greta
#           </a>
#          </b>
#         </td>
#         <td>
#          <a href="/market/distributor/Focus-Features">
#           Focus Features
#          </a>
#         </td>
#         <td class="data">
#          $43,450
#         </td>
#         <td class="data chart_down">
#          -46%
#         </td>
#         <td class="data">
#          980
#         </td>
#         <td class="data chart_grey">
#          $44
#         </td>
#         <td class="data">
#          $10,302,890
#         </td>
#         <td class="data">
#          21
#         </td>
#        </tr>
#        <tr>
#         <td class="data">
#          -
#         </td>
#         <td class="data">
#          (-)
#         </td>
#         <td>
#          <b>
#           <a href="/movie/Gloria-Bell-(2019)#tab=box-office">
#            Gloria Bell
#           </a>
#          </b>
#         </td>
#         <td>
#          <a href="/market/distributor/A24">
#           A24
#          </a>
#         </td>
#         <td class="data">
#          $31,741
#         </td>
#         <td class="data chart_down">
#          -16%
#         </td>
#         <td class="data">
#          39
#         </td>
#         <td class="data chart_grey">
#          $814
#         </td>
#         <td class="data">
#          $695,985
#         </td>
#         <td class="data">
#          14
#         </td>
#        </tr>
#        <tr bgcolor="#ffeeff">
#         <td class="data">
#          -
#         </td>
#         <td class="data">
#          (-)
#         </td>
#         <td>
#          <b>
#           <a href="/movie/Kid-The-(2019)#tab=box-office">
#            The Kid
#           </a>
#          </b>
#         </td>
#         <td>
#          <a href="/market/distributor/Lionsgate">
#           Lionsgate
#          </a>
#         </td>
#         <td class="data">
#          $30,292
#         </td>
#         <td class="data chart_down">
#          -26%
#         </td>
#         <td class="data">
#          268
#         </td>
#         <td class="data chart_grey">
#          $113
#         </td>
#         <td class="data">
#          $1,214,177
#         </td>
#         <td class="data">
#          14
#         </td>
#        </tr>
#        <tr>
#         <td class="data">
#          -
#         </td>
#         <td class="data">
#          (-)
#         </td>
#         <td>
#          <b>
#           <a href="/movie/Spider-Man-Into-The-Spider-Verse-3D-(2018)#tab=box-office">
#            Spider-Man: Into The Spider…
#           </a>
#          </b>
#         </td>
#         <td>
#          <a href="/market/distributor/Sony-Pictures">
#           Sony Pictures
#          </a>
#         </td>
#         <td class="data">
#          $29,242
#         </td>
#         <td class="data chart_down">
#          -11%
#         </td>
#         <td class="data">
#          366
#         </td>
#         <td class="data chart_grey">
#          $80
#         </td>
#         <td class="data">
#          $189,618,008
#         </td>
#         <td class="data">
#          98
#         </td>
#        </tr>
#        <tr bgcolor="#ffeeff">
#         <td class="data">
#          -
#         </td>
#         <td class="data">
#          (-)
#         </td>
#         <td>
#          <b>
#           <a href="/movie/Run-the-Race-(2019)#tab=box-office">
#            Run the Race
#           </a>
#          </b>
#         </td>
#         <td>
#          <a href="/market/distributor/Roadside-Attractions">
#           Roadside Attractions
#          </a>
#         </td>
#         <td class="data">
#          $29,179
#         </td>
#         <td class="data chart_down">
#          -24%
#         </td>
#         <td class="data">
#          446
#         </td>
#         <td class="data chart_grey">
#          $65
#         </td>
#         <td class="data">
#          $6,023,065
#         </td>
#         <td class="data">
#          28
#         </td>
#        </tr>
#        <tr>
#         <td class="data">
#          -
#         </td>
#         <td class="data">
#          (-)
#         </td>
#         <td>
#          <b>
#           <a href="/movie/Bohemian-Rhapsody-(2018)#tab=box-office">
#            Bohemian Rhapsody
#           </a>
#          </b>
#         </td>
#         <td>
#          <a href="/market/distributor/20th-Century-Fox">
#           20th Century Fox
#          </a>
#         </td>
#         <td class="data">
#          $28,857
#         </td>
#         <td class="data chart_down">
#          -6%
#         </td>
#         <td class="data">
#          256
#         </td>
#         <td class="data chart_grey">
#          $113
#         </td>
#         <td class="data">
#          $215,797,214
#         </td>
#         <td class="data">
#          140
#         </td>
#        </tr>
#        <tr bgcolor="#ffeeff">
#         <td class="data">
#          -
#         </td>
#         <td class="data">
#          (-)
#         </td>
#         <td>
#          <b>
#           <a href="/movie/Aquaman-(2018)#tab=box-office">
#            Aquaman
#           </a>
#          </b>
#         </td>
#         <td>
#          <a href="/market/distributor/Warner-Bros">
#           Warner Bros.
#          </a>
#         </td>
#         <td class="data">
#          $28,164
#         </td>
#         <td class="data chart_down">
#          -3%
#         </td>
#         <td class="data">
#          283
#         </td>
#         <td class="data chart_grey">
#          $100
#         </td>
#         <td class="data">
#          $334,548,294
#         </td>
#         <td class="data">
#          91
#         </td>
#        </tr>
#        <tr>
#         <td class="data">
#          -
#         </td>
#         <td class="data">
#          (-)
#         </td>
#         <td>
#          <b>
#           <a href="/movie/Todos-lo-saben-(Spain)-(2018)#tab=box-office">
#            Everybody Knows
#           </a>
#          </b>
#         </td>
#         <td>
#          <a href="/market/distributor/Focus-Features">
#           Focus Features
#          </a>
#         </td>
#         <td class="data">
#          $25,595
#         </td>
#         <td class="data chart_down">
#          -14%
#         </td>
#         <td class="data">
#          248
#         </td>
#         <td class="data chart_grey">
#          $103
#         </td>
#         <td class="data">
#          $2,430,981
#         </td>
#         <td class="data">
#          42
#         </td>
#        </tr>
#        <tr bgcolor="#ffeeff">
#         <td class="data">
#          -
#         </td>
#         <td class="data">
#          (-)
#         </td>
#         <td>
#          <b>
#           <a href="/movie/Star-is-Born-A-(2018)#tab=box-office">
#            A Star is Born
#           </a>
#          </b>
#         </td>
#         <td>
#          <a href="/market/distributor/Warner-Bros">
#           Warner Bros.
#          </a>
#         </td>
#         <td class="data">
#          $24,156
#         </td>
#         <td class="data chart_down">
#          -24%
#         </td>
#         <td class="data">
#          443
#         </td>
#         <td class="data chart_grey">
#          $55
#         </td>
#         <td class="data">
#          $215,181,496
#         </td>
#         <td class="data">
#          168
#         </td>
#        </tr>
#        <tr>
#         <td class="data">
#          -
#         </td>
#         <td class="data">
#          (-)
#         </td>
#         <td>
#          <b>
#           <a href="/movie/Climax-(France)-(2018)#tab=box-office">
#            Climax
#           </a>
#          </b>
#         </td>
#         <td>
#          <a href="/market/distributor/A24">
#           A24
#          </a>
#         </td>
#         <td class="data">
#          $21,565
#         </td>
#         <td class="data chart_down">
#          -37%
#         </td>
#         <td class="data">
#          217
#         </td>
#         <td class="data chart_grey">
#          $99
#         </td>
#         <td class="data">
#          $690,622
#         </td>
#         <td class="data">
#          21
#         </td>
#        </tr>
#        <tr bgcolor="#ffeeff">
#         <td class="data">
#          -
#         </td>
#         <td class="data">
#          (-)
#         </td>
#         <td>
#          <b>
#           <a href="/movie/Cold-Pursuit-(2019)#tab=box-office">
#            Cold Pursuit
#           </a>
#          </b>
#         </td>
#         <td>
#          <a href="/market/distributor/Lionsgate">
#           Lionsgate
#          </a>
#         </td>
#         <td class="data">
#          $19,097
#         </td>
#         <td class="data chart_down">
#          -23%
#         </td>
#         <td class="data">
#          376
#         </td>
#         <td class="data chart_grey">
#          $51
#         </td>
#         <td class="data">
#          $31,706,519
#         </td>
#         <td class="data">
#          42
#         </td>
#        </tr>
#        <tr>
#         <td class="data">
#          -
#         </td>
#         <td class="data">
#          (-)
#         </td>
#         <td>
#          <b>
#           <a href="/movie/Happy-Death-Day-2U-(2019)#tab=box-office">
#            Happy Death Day 2U
#           </a>
#          </b>
#         </td>
#         <td>
#          <a href="/market/distributor/Universal">
#           Universal
#          </a>
#         </td>
#         <td class="data">
#          $18,015
#         </td>
#         <td class="data chart_down">
#          -42%
#         </td>
#         <td class="data">
#          486
#         </td>
#         <td class="data chart_grey">
#          $37
#         </td>
#         <td class="data">
#          $27,653,570
#         </td>
#         <td class="data">
#          37
#         </td>
#        </tr>
#        <tr bgcolor="#ffeeff">
#         <td class="data">
#          -
#         </td>
#         <td class="data">
#          (-)
#         </td>
#         <td>
#          <b>
#           <a href="/movie/Glass-(2019)#tab=box-office">
#            Glass
#           </a>
#          </b>
#         </td>
#         <td>
#          <a href="/market/distributor/Universal">
#           Universal
#          </a>
#         </td>
#         <td class="data">
#          $17,375
#         </td>
#         <td class="data chart_down">
#          -23%
#         </td>
#         <td class="data">
#          262
#         </td>
#         <td class="data chart_grey">
#          $66
#         </td>
#         <td class="data">
#          $110,611,400
#         </td>
#         <td class="data">
#          63
#         </td>
#        </tr>
#        <tr>
#         <td class="data">
#          -
#         </td>
#         <td class="data">
#          (-)
#         </td>
#         <td>
#          <b>
#           <a href="/movie/They-Shall-Not-Grow-Old-(UK)-(2018)#tab=box-office">
#            They Shall Not Grow Old
#           </a>
#          </b>
#         </td>
#         <td>
#          <a href="/market/distributor/Warner-Bros">
#           Warner Bros.
#          </a>
#         </td>
#         <td class="data">
#          $17,002
#         </td>
#         <td class="data chart_up">
#          +19%
#         </td>
#         <td class="data">
#          150
#         </td>
#         <td class="data chart_grey">
#          $113
#         </td>
#         <td class="data">
#          $17,598,058
#         </td>
#         <td class="data">
#          95
#         </td>
#        </tr>
#        <tr bgcolor="#ffeeff">
#         <td class="data">
#          -
#         </td>
#         <td class="data">
#          (-)
#         </td>
#         <td>
#          <b>
#           <a href="/movie/Ralph-Breaks-The-Internet-(2018)#tab=box-office">
#            Ralph Breaks The Internet
#           </a>
#          </b>
#         </td>
#         <td>
#          <a href="/market/distributor/Walt-Disney">
#           Walt Disney
#          </a>
#         </td>
#         <td class="data">
#          $16,324
#         </td>
#         <td class="data chart_up">
#          +17%
#         </td>
#         <td class="data">
#          172
#         </td>
#         <td class="data chart_grey">
#          $95
#         </td>
#         <td class="data">
#          $200,867,677
#         </td>
#         <td class="data">
#          121
#         </td>
#        </tr>
#        <tr>
#         <td class="data">
#          -
#         </td>
#         <td class="data">
#          (-)
#         </td>
#         <td>
#          <b>
#           <a href="/movie/Mary-Poppins-Returns-(2018)#tab=box-office">
#            Mary Poppins Returns
#           </a>
#          </b>
#         </td>
#         <td>
#          <a href="/market/distributor/Walt-Disney">
#           Walt Disney
#          </a>
#         </td>
#         <td class="data">
#          $14,535
#         </td>
#         <td class="data chart_up">
#          +18%
#         </td>
#         <td class="data">
#          182
#         </td>
#         <td class="data chart_grey">
#          $80
#         </td>
#         <td class="data">
#          $171,738,132
#         </td>
#         <td class="data">
#          93
#         </td>
#        </tr>
#        <tr bgcolor="#ffeeff">
#         <td class="data">
#          -
#         </td>
#         <td class="data">
#          (-)
#         </td>
#         <td>
#          <b>
#           <a href="/movie/Favourite-The-(2018)#tab=box-office">
#            The Favourite
#           </a>
#          </b>
#         </td>
#         <td>
#          <a href="/market/distributor/Fox-Searchlight">
#           Fox Searchlight
#          </a>
#         </td>
#         <td class="data">
#          $11,262
#         </td>
#         <td class="data chart_down">
#          -18%
#         </td>
#         <td class="data">
#          143
#         </td>
#         <td class="data chart_grey">
#          $79
#         </td>
#         <td class="data">
#          $34,097,357
#         </td>
#         <td class="data">
#          119
#         </td>
#        </tr>
#        <tr>
#         <td class="data">
#          -
#         </td>
#         <td class="data">
#          (-)
#         </td>
#         <td>
#          <b>
#           <a href="/movie/Pajaros-de-verano-(Colombia)-(2019)#tab=box-office">
#            Birds of Passage
#           </a>
#          </b>
#         </td>
#         <td>
#          <a href="/market/distributor/Orchard-The">
#           The Orchard
#          </a>
#         </td>
#         <td class="data">
#          $10,488
#         </td>
#         <td class="data chart_up">
#          +5%
#         </td>
#         <td class="data">
#          97
#         </td>
#         <td class="data chart_grey">
#          $108
#         </td>
#         <td class="data">
#          $396,929
#         </td>
#         <td class="data">
#          37
#         </td>
#        </tr>
#        <tr bgcolor="#ffeeff">
#         <td class="data">
#          -
#         </td>
#         <td class="data">
#          (-)
#         </td>
#         <td>
#          <b>
#           <a href="/movie/Wedding-Guest-The-(UK)-(2019)#tab=box-office">
#            The Wedding Guest
#           </a>
#          </b>
#         </td>
#         <td>
#          <a href="/market/distributor/IFC-Films">
#           IFC Films
#          </a>
#         </td>
#         <td class="data">
#          $10,073
#         </td>
#         <td class="data chart_down">
#          -23%
#         </td>
#         <td class="data">
#          94
#         </td>
#         <td class="data chart_grey">
#          $107
#         </td>
#         <td class="data">
#          $263,897
#         </td>
#         <td class="data">
#          21
#         </td>
#        </tr>
#        <tr>
#         <td class="data">
#          -
#         </td>
#         <td class="data">
#          (-)
#         </td>
#         <td>
#          <b>
#           <a href="/movie/Aftermath-The-(2019)#tab=box-office">
#            The Aftermath
#           </a>
#          </b>
#         </td>
#         <td>
#          <a href="/market/distributor/Fox-Searchlight">
#           Fox Searchlight
#          </a>
#         </td>
#         <td class="data">
#          $5,786
#         </td>
#         <td class="data chart_down">
#          -3%
#         </td>
#         <td class="data">
#          5
#         </td>
#         <td class="data chart_grey">
#          $1,157
#         </td>
#         <td class="data">
#          $80,254
#         </td>
#         <td class="data">
#          7
#         </td>
#        </tr>
#        <tr bgcolor="#ffeeff">
#         <td class="data">
#          -
#         </td>
#         <td class="data">
#          (-)
#         </td>
#         <td>
#          <b>
#           <a href="/movie/Mustang-The-(2019)#tab=box-office">
#            The Mustang
#           </a>
#          </b>
#         </td>
#         <td>
#          <a href="/market/distributor/Focus-Features">
#           Focus Features
#          </a>
#         </td>
#         <td class="data">
#          $4,465
#         </td>
#         <td class="data chart_down">
#          -30%
#         </td>
#         <td class="data">
#          4
#         </td>
#         <td class="data chart_grey">
#          $1,116
#         </td>
#         <td class="data">
#          $93,989
#         </td>
#         <td class="data">
#          7
#         </td>
#        </tr>
#        <tr>
#         <td class="data">
#          -
#         </td>
#         <td class="data">
#          (-)
#         </td>
#         <td>
#          <b>
#           <a href="/movie/If-Beale-Street-Could-Talk-(2018)#tab=box-office">
#            If Beale Street Could Talk
#           </a>
#          </b>
#         </td>
#         <td>
#          <a href="/market/distributor/Annapurna-Pictures">
#           Annapurna Pictures
#          </a>
#         </td>
#         <td class="data">
#          $4,351
#         </td>
#         <td class="data chart_down">
#          -14%
#         </td>
#         <td class="data">
#          59
#         </td>
#         <td class="data chart_grey">
#          $74
#         </td>
#         <td class="data">
#          $14,864,584
#         </td>
#         <td class="data">
#          98
#         </td>
#        </tr>
#        <tr bgcolor="#ffeeff">
#         <td class="data">
#          -
#         </td>
#         <td class="data">
#          (-)
#         </td>
#         <td>
#          <b>
#           <a href="/movie/Prodigy-The-(2019)#tab=box-office">
#            The Prodigy
#           </a>
#          </b>
#         </td>
#         <td>
#          <a href="/market/distributor/Orion-Pictures">
#           Orion Pictures
#          </a>
#         </td>
#         <td class="data">
#          $3,767
#         </td>
#         <td class="data chart_down">
#          -40%
#         </td>
#         <td class="data">
#          88
#         </td>
#         <td class="data chart_grey">
#          $43
#         </td>
#         <td class="data">
#          $14,798,150
#         </td>
#         <td class="data">
#          42
#         </td>
#        </tr>
#        <tr>
#         <td class="data">
#          -
#         </td>
#         <td class="data">
#          (-)
#         </td>
#         <td>
#          <b>
#           <a href="/movie/Vice-(2018)#tab=box-office">
#            Vice
#           </a>
#          </b>
#         </td>
#         <td>
#          <a href="/market/distributor/Annapurna-Pictures">
#           Annapurna Pictures
#          </a>
#         </td>
#         <td class="data">
#          $3,099
#         </td>
#         <td class="data chart_down">
#          -19%
#         </td>
#         <td class="data">
#          47
#         </td>
#         <td class="data chart_grey">
#          $66
#         </td>
#         <td class="data">
#          $47,806,224
#         </td>
#         <td class="data">
#          87
#         </td>
#        </tr>
#        <tr bgcolor="#ffeeff">
#         <td class="data">
#          -
#         </td>
#         <td class="data">
#          (-)
#         </td>
#         <td>
#          <b>
#           <a href="/movie/Kid-Who-Would-Be-King-The-(UK)-(2019)#tab=box-office">
#            The Kid Who Would Be King
#           </a>
#          </b>
#         </td>
#         <td>
#          <a href="/market/distributor/20th-Century-Fox">
#           20th Century Fox
#          </a>
#         </td>
#         <td class="data">
#          $3,061
#         </td>
#         <td class="data chart_up">
#          +210%
#         </td>
#         <td class="data">
#          63
#         </td>
#         <td class="data chart_grey">
#          $49
#         </td>
#         <td class="data">
#          $16,768,624
#         </td>
#         <td class="data">
#          56
#         </td>
#        </tr>
#        <tr>
#         <td class="data">
#          -
#         </td>
#         <td class="data">
#          (-)
#         </td>
#         <td>
#          <b>
#           <a href="/movie/Hummingbird-Project-The-(Canada)-(2019)#tab=box-office">
#            The Hummingbird Project
#           </a>
#          </b>
#         </td>
#         <td>
#          <a href="/market/distributor/Orchard-The">
#           The Orchard
#          </a>
#         </td>
#         <td class="data">
#          $2,527
#         </td>
#         <td class="data chart_down">
#          -15%
#         </td>
#         <td class="data">
#          4
#         </td>
#         <td class="data chart_grey">
#          $632
#         </td>
#         <td class="data">
#          $45,115
#         </td>
#         <td class="data">
#          7
#         </td>
#        </tr>
#        <tr bgcolor="#ffeeff">
#         <td class="data">
#          -
#         </td>
#         <td class="data">
#          (-)
#         </td>
#         <td>
#          <b>
#           <a href="/movie/Total-Dhamaal-(India)-(2019)#tab=box-office">
#            Total Dhamaal
#           </a>
#          </b>
#         </td>
#         <td>
#          <a href="/market/distributor/FIP">
#           FIP
#          </a>
#         </td>
#         <td class="data">
#          $2,229
#         </td>
#         <td class="data chart_down">
#          -27%
#         </td>
#         <td class="data">
#          54
#         </td>
#         <td class="data chart_grey">
#          $41
#         </td>
#         <td class="data">
#          $2,167,632
#         </td>
#         <td class="data">
#          28
#         </td>
#        </tr>
#        <tr>
#         <td class="data">
#          -
#         </td>
#         <td class="data">
#          (-)
#         </td>
#         <td>
#          <b>
#           <a href="/movie/Destroyer-(2018)#tab=box-office">
#            Destroyer
#           </a>
#          </b>
#         </td>
#         <td>
#          <a href="/market/distributor/Annapurna-Pictures">
#           Annapurna Pictures
#          </a>
#         </td>
#         <td class="data">
#          $667
#         </td>
#         <td class="data chart_up">
#          +43%
#         </td>
#         <td class="data">
#          12
#         </td>
#         <td class="data chart_grey">
#          $56
#         </td>
#         <td class="data">
#          $1,533,324
#         </td>
#         <td class="data">
#          87
#         </td>
#        </tr>
#        <tr bgcolor="#ffeeff">
#         <td class="data">
#          -
#         </td>
#         <td class="data">
#          (-)
#         </td>
#         <td>
#          <b>
#           <a href="/movie/Creed-II-(2018)#tab=box-office">
#            Creed II
#           </a>
#          </b>
#         </td>
#         <td>
#          <a href="/market/distributor/MGM">
#           MGM
#          </a>
#         </td>
#         <td class="data">
#          $209
#         </td>
#         <td class="data chart_up">
#          +18%
#         </td>
#         <td class="data">
#          8
#         </td>
#         <td class="data chart_grey">
#          $26
#         </td>
#         <td class="data">
#          $115,715,889
#         </td>
#         <td class="data">
#          121
#         </td>
#        </tr>
#        <tr>
#         <td class="data">
#          -
#         </td>
#         <td class="data">
#          (-)
#         </td>
#         <td>
#          <b>
#           <a href="/movie/Uri-The-Surgical-Strike-(India)-(2019)#tab=box-office">
#            Uri: The Surgical Strike
#           </a>
#          </b>
#         </td>
#         <td>
#          <a href="/market/distributor/PackYourBag-Films">
#           PackYourBag Films
#          </a>
#         </td>
#         <td class="data">
#          $160
#         </td>
#         <td class="data chart_down">
#          -72%
#         </td>
#         <td class="data">
#          5
#         </td>
#         <td class="data chart_grey">
#          $32
#         </td>
#         <td class="data">
#          $4,184,759
#         </td>
#         <td class="data">
#          70
#         </td>
#        </tr>
#        <tr bgcolor="#ffeeff">
#         <td class="data">
#          -
#         </td>
#         <td class="data">
#          (-)
#         </td>
#         <td>
#          <b>
#           <a href="/movie/Ce-magnifique-gateau-(Belgium)-(2019)#tab=box-office">
#            This Magnificent Cake!
#           </a>
#          </b>
#         </td>
#         <td>
#          <a href="/market/distributor/GKIDS">
#           GKIDS
#          </a>
#         </td>
#         <td class="data">
#          $94
#         </td>
#         <td class="data chart_up">
#          +74%
#         </td>
#         <td class="data">
#          2
#         </td>
#         <td class="data chart_grey">
#          $47
#         </td>
#         <td class="data">
#          $3,503
#         </td>
#         <td class="data">
#          21
#         </td>
#        </tr>
#       </table>
#      </center>
#      <center>
#       <small>
#        Our box office charts are compiled from data provided to us by distributors.  To be included on our charts, please send reports to bodata@the-numbers.com.
#       </small>
#      </center>
#      <br/>
#     </div>
#     <a href="https://beta.productionnext.com/register/the-numbers">
#      <img alt="ProductionNext" border="0" height="90" src="/images/pn-banner-official.gif" style="margin:auto; display:block; padding:3px;" width="728"/>
#     </a>
#     <center>
#      <div id="rcjsload_7ce5b7">
#      </div>
#      <script type="text/javascript">
#       (function() {
# var referer="";try{if(referer=document.referrer,"undefined"==typeof referer)throw"undefined"}catch(exception){referer=document.location.href,(""==referer||"undefined"==typeof referer)&&(referer=document.URL)}referer=referer.substr(0,700);
# var rcel = document.createElement("script");
# rcel.id = 'rc_' + Math.floor(Math.random() * 1000);
# rcel.type = 'text/javascript';
# rcel.src = "https://trends.revcontent.com/serve.js.php?w=71375&t="+rcel.id+"&c="+(new Date()).getTime()+"&width="+(window.outerWidth || document.documentElement.clientWidth)+"&referer="+referer;
# rcel.async = true;
# var rcds = document.getElementById("rcjsload_7ce5b7"); rcds.appendChild(rcel);
# })();
#      </script>
#     </center>
#    </div>
#    <div id="sidebar">
#     <h1>
#      Trending Pages
#     </h1>
#     <ul style="display: inline-block;font-size: 100%;">
#      <li>
#       <a href="/bankability">
#        <span style="color: #008255">
#         Bankability Index
#        </span>
#       </a>
#      </li>
#      <li>
#       <a href="/daily-box-office-chart">
#        Daily Box Office
#       </a>
#      </li>
#      <li>
#       <a href="/weekend-box-office-chart">
#        Weekend Box Office
#       </a>
#      </li>
#      <li>
#       <a href="/weekly-box-office-chart">
#        Weekly Box Office
#       </a>
#      </li>
#      <li>
#       <a href="/weekly-dvd-sales-chart">
#        Weekly DVD Sales
#       </a>
#      </li>
#      <li>
#       <a href="/weekly-bluray-sales-chart">
#        Weekly Blu-ray Sales
#       </a>
#      </li>
#      <li>
#       <a href="/home-market/dvd-sales/2019">
#        Top DVDs of 2019
#       </a>
#      </li>
#      <li>
#       <a href="/home-market/bluray-sales/2019">
#        Top Blu-rays of 2019
#       </a>
#      </li>
#     </ul>
#     <ul style="padding: 5px;display: inline-block;font-size: 100%;">
#      <li>
#       <a href="/movies/release-schedule">
#        Release Schedule
#       </a>
#      </li>
#      <li>
#       <a href="/movies/comparisons/All-Time-Top-Grossing-Films">
#        Top Grossing Films
#       </a>
#      </li>
#      <li>
#       <a href="/box-office-records/">
#        Theatrical Records
#       </a>
#      </li>
#      <li>
#       <a href="/movie/budgets/">
#        Movie Budgets
#       </a>
#      </li>
#      <li>
#       <a href="/market/">
#        Theatrical Market
#       </a>
#      </li>
#      <li>
#       <a href="/movies/report-builder">
#        Report Builder
#       </a>
#      </li>
#      <li>
#       <a href="/box-office-star-records/">
#        Star Records
#       </a>
#      </li>
#      <li>
#       <a href="/people/records/highest-grossing-stars/2019">
#        Top Stars of 2019
#       </a>
#      </li>
#     </ul>
#     <center>
#      <h1>
#       Search
#      </h1>
#      <form action="/search" method="get">
#       <input name="searchterm" onkeyup="if (event.keyCode == 13) { this.form.submit(); return false; }" size="36" type="text" value=""/>
#      </form>
#     </center>
#     <br/>
#     <center>
#      <script type="text/javascript">
#       <!--
# e9 = new Object();
# e9.size = "300x250";
# //-->
#      </script>
#      <script src="//tags.expo9.exponential.com/tags/TheNumbers/ROS/tags.js" type="text/javascript">
#      </script>
#     </center>
#     <h1>
#      <a class="inh1" href="/movies/most-anticipated">
#       Most Anticipated Movies
#      </a>
#     </h1>
#     <ul>
#      <li>
#       <a href="/movie/Avengers-Endgame-(2019)#tab=summary">
#        Avengers: Endgame
#       </a>
#      </li>
#      <li>
#       <a href="/movie/Us-(2019)#tab=summary">
#        Us
#       </a>
#      </li>
#      <li>
#       <a href="/movie/Star-Wars-Ep-IX-(2019)#tab=summary">
#        Star Wars: Ep. IX
#       </a>
#      </li>
#      <li>
#       <a href="/movie/John-Wick-Chapter-3-Parabellum-(2019)#tab=summary">
#        John Wick: Chapter 3 â Parabellum
#       </a>
#      </li>
#      <li>
#       <a href="/movie/Dora-and-the-Lost-City-of-Gold-(2019)#tab=summary">
#        Dora and the Lost City of Gold
#       </a>
#      </li>
#      <li>
#       <a href="/movie/Dumbo-(2019)#tab=summary">
#        Dumbo
#       </a>
#      </li>
#      <li>
#       <a href="/movie/Pokemon-Detective-Pikachu-(2019)#tab=summary">
#        PokÃ©mon: Detective Pikachu
#       </a>
#      </li>
#      <li>
#       <a href="/movie/Hellboy-(2019)#tab=summary">
#        Hellboy
#       </a>
#      </li>
#      <li>
#       <a href="/movie/Shazam-(2019)#tab=summary">
#        Shazam!
#       </a>
#      </li>
#      <li>
#       <a href="/movie/Best-of-Enemies-The-(2019)#tab=summary">
#        The Best of Enemies
#       </a>
#      </li>
#     </ul>
#     <center>
#      <!-- Conversant Media 300x250 Medium Rectangle CODE for The Numbers -->
#      <script type="text/javascript">
#       var vclk_options = {sid:10990,media_id:6,media_type:8,version:"1.4",secure:"on"};
#      </script>
#      <script class="vclk_pub_code" src="https://secure.cdn.fastclick.net/js/adcodes/pubcode.min.js?sid=10990&amp;media_id=6&amp;media_type=8&amp;version=1.4&amp;exc=1" type="text/javascript">
#      </script>
#      <noscript>
#       <a href="https://secure.fastclick.net/w/click.here?sid=10990&amp;m=6&amp;c=1" target="_blank">
#        <img border="1" height="250" src="https://secure.fastclick.net/w/get.media?sid=10990&amp;m=6&amp;tp=8&amp;d=s&amp;c=1&amp;vcm_acv=1.4" width="300"/>
#       </a>
#      </noscript>
#      <!-- Conversant Media 300x250 Medium Rectangle CODE for The Numbers -->
#     </center>
#     <h1>
#      <a class="inh1" href="/movies/trending">
#       Trending Movies
#      </a>
#     </h1>
#     <ul>
#      <li>
#       <a href="/movie/Captain-Marvel-(2019)#tab=summary">
#        Captain Marvel
#       </a>
#      </li>
#      <li>
#       <a href="/movie/Alita-Battle-Angel-(2019)#tab=summary">
#        Alita: Battle Angel
#       </a>
#      </li>
#      <li>
#       <a href="/movie/Solo-A-Star-Wars-Story#tab=summary">
#        Solo: A Star Wars Story
#       </a>
#      </li>
#      <li>
#       <a href="/movie/Isnt-it-Romantic-(2019)#tab=summary">
#        Isnât it Romantic
#       </a>
#      </li>
#      <li>
#       <a href="/movie/Aquaman-(2018)#tab=summary">
#        Aquaman
#       </a>
#      </li>
#      <li>
#       <a href="/movie/Bohemian-Rhapsody-(2018)#tab=summary">
#        Bohemian Rhapsody
#       </a>
#      </li>
#      <li>
#       <a href="/movie/How-to-Train-Your-Dragon-The-Hidden-World-(2019)#tab=summary">
#        How to Train Your Dragon: The Hidden World
#       </a>
#      </li>
#      <li>
#       <a href="/movie/Avengers-Infinity-War#tab=summary">
#        Avengers: Infinity War
#       </a>
#      </li>
#      <li>
#       <a href="/movie/Mustang-The-(2019)#tab=summary">
#        The Mustang
#       </a>
#      </li>
#      <li>
#       <a href="/movie/Black-Panther#tab=summary">
#        Black Panther
#       </a>
#      </li>
#     </ul>
#     <center>
#      <!-- Insticator API Fire Widget -->
#      <div id="insticator-container">
#       <div id="div-insticator-ad-1">
#       </div>
#       <div id="insticator-embed">
#       </div>
#       <div id="div-insticator-ad-2">
#       </div>
#       <script data-cfasync="false" type="text/javascript">
#        /*<![CDATA[*/Insticator.ad.loadAd("div-insticator-ad-1");Insticator.ad.loadAd("div-insticator-ad-2");Insticator.load("em",{id : "26fd9024-230f-4e85-8bb3-d545d8a710d4"})/*]]>*/
#       </script>
#      </div>
#      <!-- End Insticator API Fire Widget -->
#     </center>
#     <h1>
#      <a class="inh1" href="/people/trending">
#       Trending People
#      </a>
#     </h1>
#     <ul style="display: inline-block;font-size: 100%;">
#      <li>
#       <a href="/person/670401-L-Jackson-Samuel">
#        Samuel L. Jackson
#       </a>
#      </li>
#      <li>
#       <a href="/person/327230401-Jordan-Peele">
#        Jordan Peele
#       </a>
#      </li>
#      <li>
#       <a href="/person/44170401-Idris-Elba">
#        Idris Elba
#       </a>
#      </li>
#      <li>
#       <a href="/person/650401-Tom-Hanks">
#        Tom Hanks
#       </a>
#      </li>
#      <li>
#       <a href="/person/540401-Tom-Cruise">
#        Tom Cruise
#       </a>
#      </li>
#     </ul>
#     <ul style="display: inline-block;font-size: 100%;">
#      <li>
#       <a href="/person/41500401-Jr-Downey-Robert">
#        Robert Downey, Jr.
#       </a>
#      </li>
#      <li>
#       <a href="/person/153250401-Owen-Wilson">
#        Owen Wilson
#       </a>
#      </li>
#      <li>
#       <a href="/person/374640401-Amy-Schumer">
#        Amy Schumer
#       </a>
#      </li>
#      <li>
#       <a href="/person/1470401-Keanu-Reeves">
#        Keanu Reeves
#       </a>
#      </li>
#      <li>
#       <a href="/person/82280401-Brie-Larson">
#        Brie Larson
#       </a>
#      </li>
#     </ul>
#     <center>
#      <!-- Insticator API Fire Widget Ads Code -->
#      <div id="div-insticator-ad-3">
#      </div>
#      <script data-cfasync="false" type="text/javascript">
#       /*<![CDATA[*/Insticator.ad.loadAd("div-insticator-ad-3");/*]]>*/
#      </script>
#      <!-- End Insticator API Fire Widget Ads Code -->
#     </center>
#    </div>
#    <div id="footer">
#     <b>
#      © 1997-2019
#      <a href="https://www.opusdata.com" rel="nofollow">
#       Nash Information Services, LLC
#      </a>
#      . All rights reserved.
#     </b>
#     <br/>
#     <b>
#      The Numbers is a registered trademark of Nash Information Services, LLC
#     </b>
#     <br/>
#     <b>
#      For comments or corrections, please email us at
#      <a href="mailto:corrections@the-numbers.com">
#       corrections@the-numbers.com
#      </a>
#     </b>
#     <br/>
#     <br/>
#     <a href="/privacy">
#      Privacy Policy
#     </a>
#     -
#     <a href="/about">
#      About Us
#     </a>
#     -
#     <a href="/glossary">
#      Glossary
#     </a>
#    </div>
#   </div>
#   <!-- NextMillennium Ads -->
#   <script type="text/javascript">
#    (function() {var s=document.createElement('script'); s.type='text/javascript'; s.async=true; s.src='//nextmillennium.liqwid.net/?key=D85D-A6F1-B041-B88A'; var x=document.getElementsByTagName('script')[0]; x.parentNode.insertBefore(s,x);})();
#   </script>
#   <!-- End of NextMillennium Ads -->
#  </body>
# </html>

# %% [markdown]
# # Beautiful Soup
#
# Beautiful Soup is a Python package for parsing HTML and XML documents. It creates a parse tree for parsed pages that can be used to extract data from HTML, which is useful for web scraping
#
# ## Installation
#   pip install beautifulsoup4

# %% [markdown]
# ## Let's Begin
# ***
#
# ### BeautifulSoup(HTML_Source , parser)
#
# <code>soup = BeautifulSoup(markup,'html.parser')</code>

# %% [markdown]
# ### Parsers
#
# <b>html.parser</b> - <code>BeautifulSoup(markup, "html.parser")</code>
#
# Advantages: Batteries included, Decent speed, Lenient (as of Python 2.7.3 and 3.2.)
#
# Disadvantages: Not very lenient (before Python 2.7.3 or 3.2.2)
#
# <b>lxml</b> - <code>BeautifulSoup(markup, "lxml")</code>
#
# Advantages: Very fast, Lenient
#
# Disadvantages: External C dependency
#
# <b>html5lib</b> - <code>BeautifulSoup(markup, "html5lib")</code>
#
# Advantages: Extremely lenient, Parses pages the same way a web browser does, Creates valid HTML5
#
# Disadvantages: Very slow, External Python dependency

# %% [markdown]
# ##### What is returned to soup?
#
# BeautifulSoup() returns a Navigatable Tree:
#
# <img src="https://cdn-images-1.medium.com/max/1600/0*ETFzXPCNHkPpqNv_.png"/>

# %%
from bs4 import BeautifulSoup

html_doc = """
<html><head><title>The Dormouse's story</title>
</head><body><p class="title">
<b>The Dormouse's story</b></p>
<p class="story">
Once upon a time there were three little sisters; and their names were
<a class="sister" href="http://example.com/elsie" id="link1">
Elsie</a>,<a class="sister" href="http://example.com/lacie" id="link2">
Lacie</a> and
<a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>
; and they lived at the bottom of a well.
</p> </body> </html>"""

soup = BeautifulSoup(html_doc,'html.parser')

# %%
print(soup.prettify())
# Out:
# <html>
#  <head>
#   <title>
#    The Dormouse's story
#   </title>
#  </head>
#  <body>
#   <p class="title">
#    <b>
#     The Dormouse's story
#    </b>
#   </p>
#   <p class="story">
#    Once upon a time there were three little sisters; and their names were
#    <a class="sister" href="http://example.com/elsie" id="link1">
#     Elsie
#    </a>
#    ,
#    <a class="sister" href="http://example.com/lacie" id="link2">
#     Lacie
#    </a>
#    and
#    <a class="sister" href="http://example.com/tillie" id="link3">
#     Tillie
#    </a>
#    ; and they lived at the bottom of a well.
#   </p>
#  </body>
# </html>

# %% [markdown]
# # Some Important Concepts
# ***
# ### Tags:
# A Tag object corresponds to an XML or HTML tag in the original document.
#
# <b><code>p</code>,<code>b</code>,<code>a</code>,<code>head</code>,<code>title</code></b> and many more.
#
#
# To scrape data from a tag : <code><soup.tag_name></code>

# %%
tag = soup.a
tag
# Out:
# <a class="sister" href="http://example.com/elsie" id="link1">
# Elsie</a>

# %%
print("Getting attributes : ",tag['href'],tag['class'],tag['id'],tag.contents,tag.string,sep='\n')
# Out:
# Getting attributes :
# http://example.com/elsie
# ['sister']
# link1
# ['\nElsie']
#
# Elsie

# %%
print("Navigating the Tress\n\n")

print("soup.head :\n",soup.head)
print("\nsoup.title :\n",soup.title)

#note difference between following
print("\nsoup.a :\n",soup.a)
print("\nsoup('a') :\n",soup('a'))
print("\nsoup.find_all('a') :\n",soup.find_all('a'))

print("\nsoup.p :\n",soup.p)
print("\nsoup.get_text() :\n",soup.get_text())
# Out:
# Navigating the Tress
#
#
# soup.head :
#  <head><title>The Dormouse's story</title>
# </head>
#
# soup.title :
#  <title>The Dormouse's story</title>
#
# soup.a :
#  <a class="sister" href="http://example.com/elsie" id="link1">
# Elsie</a>
#
# soup('a') :
#  [<a class="sister" href="http://example.com/elsie" id="link1">
# Elsie</a>, <a class="sister" href="http://example.com/lacie" id="link2">
# Lacie</a>, <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>]
#
# soup.find_all('a') :
#  [<a class="sister" href="http://example.com/elsie" id="link1">
# Elsie</a>, <a class="sister" href="http://example.com/lacie" id="link2">
# Lacie</a>, <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>]
#
# Using Get to extract links:
# http://example.com/elsie
# http://example.com/lacie
# http://example.com/tillie
#
# soup.p :
#  <p class="title">
# <b>The Dormouse's story</b></p>
#
# soup.get_text() :
#
# The Dormouse's story
#
# The Dormouse's story
#
# Once upon a time there were three little sisters; and their names were
#
# Elsie,
# Lacie and
# Tillie
# ; and they lived at the bottom of a well.

# %%
print(soup.a.name)
print(soup.a.contents)
print(soup.a.string)
# Out:
# a
# ['\nElsie']
#
# Elsie

# %% [markdown]
# ## Parents and Children

# %%
block = soup.a

for elem in block.parents:
    print(elem.name)
# Out:
# p
# body
# html
# [document]

# %%
for elem in soup.body.children:
    print(elem)
# Out:
# <p class="title">
# <b>The Dormouse's story</b></p>
#
#
# <p class="story">
# Once upon a time there were three little sisters; and their names were
# <a class="sister" href="http://example.com/elsie" id="link1">
# Elsie</a>,<a class="sister" href="http://example.com/lacie" id="link2">
# Lacie</a> and
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>
# ; and they lived at the bottom of a well.
# </p>

# %% [markdown]
# ## Find

# %%
soup.find('b')
# Out:
# <b>The Dormouse's story</b>

# %%
soup.find(id="link3")
# Out:
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>

# %%
soup.find(class_="story")
# Out:
# <p class="story">
# Once upon a time there were three little sisters; and their names were
# <a class="sister" href="http://example.com/elsie" id="link1">
# Elsie</a>,<a class="sister" href="http://example.com/lacie" id="link2">
# Lacie</a> and
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>
# ; and they lived at the bottom of a well.
# </p>

# %% [markdown]
# ### Next/Previous Siblings
#
# Points to next/previous element on same level in tree

# %%
elem = soup.a
elem
# Out:
# <a class="sister" href="http://example.com/elsie" id="link1">
# Elsie</a>

# %%
elem.next_sibling
# Out:
# ','

# %%
elem.next_sibling.next_sibling
# Out:
# <a class="sister" href="http://example.com/lacie" id="link2">
# Lacie</a>

# %% [markdown]
# ### Next/Previous Element
#
# Points to next/previous element in tree

# %%
elem = soup.a
elem
# Out:
# <a class="sister" href="http://example.com/elsie" id="link1">
# Elsie</a>

# %%
elem.next_element
# Out:
# '\nElsie'

# %%
elem.next_element.next_element
# Out:
# ','

# %%
elem.next_element.next_element.next_element
# Out:
# <a class="sister" href="http://example.com/lacie" id="link2">
# Lacie</a>

# %%
elem.previous_element
# Out:
# '\nOnce upon a time there were three little sisters; and their names were\n'

# %% [markdown]
# ### Searching in the Tree
# Beautiful Soup defines a lot of methods for searching the parse tree, but they’re all very similar. I’m going to spend a lot of time explaining the two most popular methods: <code>find()</code> and <code>find_all()</code>.

# %%
soup.find_all('p')
# Out:
# [<p class="title">
#  <b>The Dormouse's story</b></p>, <p class="story">
#  Once upon a time there were three little sisters; and their names were
#  <a class="sister" href="http://example.com/elsie" id="link1">
#  Elsie</a>,<a class="sister" href="http://example.com/lacie" id="link2">
#  Lacie</a> and
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>
#  ; and they lived at the bottom of a well.
#  </p>]

# %%
soup.find_all(["a", "b"])
# Out:
# [<b>The Dormouse's story</b>,
#  <a class="sister" href="http://example.com/elsie" id="link1">
#  Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">
#  Lacie</a>,
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>]

# %%
for sp in soup.find_all(True):
    print(sp)
# Out:
# <html><head><title>The Dormouse's story</title>
# </head><body><p class="title">
# <b>The Dormouse's story</b></p>
# <p class="story">
# Once upon a time there were three little sisters; and their names were
# <a class="sister" href="http://example.com/elsie" id="link1">
# Elsie</a>,<a class="sister" href="http://example.com/lacie" id="link2">
# Lacie</a> and
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>
# ; and they lived at the bottom of a well.
# </p> </body> </html>
# <head><title>The Dormouse's story</title>
# </head>
# <title>The Dormouse's story</title>
# <body><p class="title">
# <b>The Dormouse's story</b></p>
# <p class="story">
# Once upon a time there were three little sisters; and their names were
# <a class="sister" href="http://example.com/elsie" id="link1">
# Elsie</a>,<a class="sister" href="http://example.com/lacie" id="link2">
# Lacie</a> and
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>
# ; and they lived at the bottom of a well.
# </p> </body>
# <p class="title">
# <b>The Dormouse's story</b></p>
# <b>The Dormouse's story</b>
# <p class="story">
# Once upon a time there were three little sisters; and their names were
# <a class="sister" href="http://example.com/elsie" id="link1">
# Elsie</a>,<a class="sister" href="http://example.com/lacie" id="link2">
# Lacie</a> and
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>
# ; and they lived at the bottom of a well.
# </p>
# <a class="sister" href="http://example.com/elsie" id="link1">
# Elsie</a>
# <a class="sister" href="http://example.com/lacie" id="link2">
# Lacie</a>
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>

# %%
for sp in soup.find_all(True):
    print(sp.name)
# Out:
# html
# head
# title
# body
# p
# b
# p
# a
# a
# a

# %% [markdown]
# ### Search via CSS selectors
# <table style="width:100% ; font-size:18px">
# <tbody><tr>
#     <th>Selector</th>
#     <th>Example</th>
#     <th>Example description</th>
#   </tr>
#   <tr>
#     <td><a href="sel_class.asp">.<i>class</i></a></td>
#     <td class="notranslate">.intro</td>
#     <td>Selects all elements with class="intro"</td>
#   </tr>
#   <tr>
#     <td><a href="sel_id.asp">#<i>id</i></a></td>
#     <td class="notranslate">#firstname</td>
#     <td>Selects the element with id="firstname"</td>
#   </tr>
#     </tbody>
#     </table>

# %%
css_soup = BeautifulSoup(
'''
<p class="body strikeout"></p>
<a id = "link" class = "my"></a>
'''
,'html.parser')

#If you want to search for tags that match two or more CSS classes, you should use a CSS selector
print(css_soup.select(".strikeout"))
print(css_soup.select("#link"))
# Out:
# [<p class="body strikeout"></p>]
# [<a class="my" id="link"></a>]

# %%
soup.select("head > title")
# Out:
# [<title>The Dormouse's story</title>]

# %%
soup.select("p > #link1")
# Out:
# [<a class="sister" href="http://example.com/elsie" id="link1">
#  Elsie</a>]

# %%
soup.select("a#link1")
# Out:
# [<a class="sister" href="http://example.com/elsie" id="link1">
#  Elsie</a>]

# %%
soup.select_one(".sister")
# Out:
# <a class="sister" href="http://example.com/elsie" id="link1">
# Elsie</a>

# %% [markdown]
# ### Some other examples of Searching

# %%
soup.find(class_ = "sister" , id='link1')
# Out:
# <a class="sister" href="http://example.com/elsie" id="link1">
# Elsie</a>

# %%
soup.find_all('a',{'class':'sister'})
# Out:
# [<a class="sister" href="http://example.com/elsie" id="link1">
#  Elsie</a>, <a class="sister" href="http://example.com/lacie" id="link2">
#  Lacie</a>, <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>]

# %%
soup.find_all('a',{'class':'sister' , 'id' : 'link3'})
# Out:
# [<a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>]

# %%
#Find tags that match any selector from a list of selectors:
soup.select("#link1,#link2")
# Out:
# [<a class="sister" href="http://example.com/elsie" id="link1">
#  Elsie</a>, <a class="sister" href="http://example.com/lacie" id="link2">
#  Lacie</a>]

# %%
#Test for the existence of an attribute:
soup.select('a[href]')
# Out:
# [<a class="sister" href="http://example.com/elsie" id="link1">
#  Elsie</a>, <a class="sister" href="http://example.com/lacie" id="link2">
#  Lacie</a>, <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>]

# %%
soup.select('a[href="http://example.com/elsie"]')
# Out:
# [<a class="sister" href="http://example.com/elsie" id="link1">
#  Elsie</a>]

# %%
#common task is to get links off a website
print("\nUsing Get to extract links:")
for link in soup.find_all('a'):
    print(link.get('href'))
# Out:
# Using Get to extract links:
# http://example.com/elsie
# http://example.com/lacie
# http://example.com/tillie
